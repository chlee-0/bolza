# %%
from bolza import non_prim_conj_classes2, ls_count

# %%
non_prim_conj_classes2(11, write_file = True)
ls_count('bolza_nonprim.txt', saveQ = True)
# Out:
# working on:  2
# 2 : time for preprocessing 9.5367431640625e-07
# 3 0
# 2 : time of execution 0.001013040542602539
# number of new words 56
# working on:  3
# 3 : time for preprocessing 9.5367431640625e-07
# 31 0
# 3 : time of execution 0.005373954772949219
# number of new words 392
# working on:  4
# 4 : time for preprocessing 9.5367431640625e-07
# 146 0
# 4 : time of execution 0.04242300987243652
# number of new words 2736
# working on:  5
# 5 : time for preprocessing 9.5367431640625e-07
# 7607 0
# 5 : time of execution 0.2503988742828369
# number of new words 19096
# working on:  6
# 6 : time for preprocessing 1.1920928955078125e-06
# 20245 0
# 74325 10000
# 6 : time of execution 1.784135341644287
# number of new words 133288
# bolza_nonprim.txt : time for processing 1.2294912338256836
# writing to ls_bolza_nonprim.txt
# {(5, 4): 48,
#  (25, 17): 48,
#  (113, 80): 32,
#  (521, 369): 32,
#  (2405, 1700): 80,
#  (11089, 7841): 16,
#  (51137, 36160): 16,
#  (235825, 166753): 16,
# ...
